# %% [markdown]
# # Setup initial code environment
#
# 1) Make sure we can reload python files when we make changes.
# 2) Load the base-notebook which will download all the python utility files and check versions of TensorFlow and Python.
# 3) Setup imports we will need for this notebook

# %%
# %run ../../base-notebook.ipynb
# Out:
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/contents.txt [666/666] -> "../../ext/contents.txt" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_callback.py [8151/8151] -> "../../ext/ml_callback.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_internal.py [2478/2478] -> "../../ext/ml_internal.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_io.py [1572/1572] -> "../../ext/ml_io.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_layer.py [7416/7416] -> "../../ext/ml_layer.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_plot.py [12765/12765] -> "../../ext/ml_plot.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_util.py [2061/2061] -> "../../ext/ml_util.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_data.py [5991/5991] -> "../../ext/ml_data.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_view.py [3304/3304] -> "../../ext/ml_view.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_analyze.py [241/241] -> "../../ext/ml_analyze.py" [1]
# FINISHED --2023-06-04 21:52:13--
# Total wall clock time: 0.2s
# Downloaded: 9 files, 43K in 0.002s (18.2 MB/s)
# TensorFlow version: 2.12.0
# Python version 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:25:13) [Clang 14.0.6 ]

# %%
import sys
import os

sys.path.append("../../ext")

import ext.ml_callback as mlc
import ext.ml_io as mli
import ext.ml_layer as mll
import ext.ml_plot as mlp
import ext.ml_util as mlu
import ext.ml_data as mld
import ext.ml_view as mlv
import ext.ml_internal as mlint

import tensorflow as tf

import opendatasets as od

from keras import Sequential, Model
from keras.optimizers import Adam
from keras.layers import Dense, Activation, RandomFlip, RandomZoom, RandomHeight, \
    RandomWidth, RandomRotation, Input, GlobalAveragePooling2D, Rescaling, Conv2D, \
    MaxPool2D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.utils import image_dataset_from_directory

# %% [markdown]
# # Configure mixed-precision so we can improve the performance

# %%
# BASE_MODEL_NAME is used as a folder name for saved models.
IMG_SHAPE = (224, 224)

# %%
mlu.set_mixed_precision_policy_for_gpu()
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   METAL, no compute capability (probably not an Nvidia GPU)
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %% [markdown]
# # Download the dataset from Kaggle (kaggle.json API key neccesary)

# %%
# Download the dogs and cats dataset
od.download_kaggle_dataset(dataset_url="https://www.kaggle.com/datasets/chetankv/dogs-cats-images/download?datasetVersionNumber=1",
                           data_dir="./data")
# Out:
# Downloading dogs-cats-images.zip to ./data/dogs-cats-images
# 100%|██████████| 435M/435M [00:13<00:00, 34.7MB/s]

# %% [markdown]
# # Inspect the contents of the downloaded dataset

# %%
train_dir = "./data/dogs-cats-images/dataset/training_set"
test_dir = "./data/dogs-cats-images/dataset/test_set"

# %%
mli.list_dir_summary(train_dir)
# Out:
# There are 2 directories, and 1 in ./data/dogs-cats-images/dataset/training_set
# There are 0 directories, and 4000 in ./data/dogs-cats-images/dataset/training_set/dogs
# There are 0 directories, and 4000 in ./data/dogs-cats-images/dataset/training_set/cats

# %%
mli.list_dir_summary(test_dir)
# Out:
# There are 2 directories, and 0 in ./data/dogs-cats-images/dataset/test_set
# There are 0 directories, and 1000 in ./data/dogs-cats-images/dataset/test_set/dogs
# There are 0 directories, and 1000 in ./data/dogs-cats-images/dataset/test_set/cats

# %% [markdown]
# # Show some random images from disk of the downloaded dataset

# %%
mlv.show_random_image_from_disk(target_dir=train_dir, target_class="dogs")

# %%
mlv.show_random_image_from_disk(target_dir=train_dir, target_class="cats")

# %% [markdown]
# # Create datasets for the train and test images

# %%
train_images = image_dataset_from_directory(directory=train_dir,
                             label_mode="categorical",
                             batch_size=32,
                             image_size=IMG_SHAPE,
                             shuffle=True)

test_images = image_dataset_from_directory(directory=test_dir,
                             label_mode="categorical",
                             batch_size=32,
                             image_size=IMG_SHAPE,
                             shuffle=True)

len(train_images), len(test_images)
# Out:
# Found 8000 files belonging to 2 classes.
# Metal device set to: Apple M1 Max
# Found 2000 files belonging to 2 classes.
# (250, 63)

# %% [markdown]
# # Get class-names from the dataset

# %%
class_names = mld.get_class_names_from_dataset(train_images)
class_names
# Out:
# ['cats', 'dogs']

# %% [markdown]
# # Inspect some random images from the dataset to check image size, and quality

# %%
mlv.show_images_from_dataset(dataset=train_images, shape=(4, 8))

# %% [markdown]
# # Create data augmentation layers for training

# %%
data_augementation_layer = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(.2),
    RandomHeight(.2),
    RandomWidth(.2),
    RandomZoom(.2),
    Rescaling(1/255.),
], name="data_augmentation")

# %% [markdown]
# # Create the model

# %%
def conv_layer(x, filters, kernel_size=(2, 2), padding="valid"):
    x = Conv2D(filters=filters, kernel_size=kernel_size, activation="relu", padding=padding)(x)
    x = BatchNormalization()(x)
    return MaxPool2D(pool_size=(2, 2))(x)
    # return Dropout(rate=.25)(x)

input_layer = Input(shape=IMG_SHAPE + (3,), name="input_layer")
x = data_augementation_layer(input_layer)
x = conv_layer(x=x, filters=16, kernel_size=(3, 3))
x = conv_layer(x=x, filters=32, kernel_size=(3, 3))
x = conv_layer(x=x, filters=64, kernel_size=(3, 3))
x = GlobalAveragePooling2D()(x)
x = Dense(units=16, activation="relu")(x)
x = Dense(units=len(class_names), name="output_dense_layer")(x)
output_layer = Activation(activation="softmax", dtype=tf.float32, name="output_activation_layer")(x)

model = Model(input_layer, output_layer)

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(learning_rate=0.002),
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  conv2d (Conv2D)             (None, None, None, 16)    448
#
#  batch_normalization (BatchN  (None, None, None, 16)   64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, None, None, 16)   0
#  )
#
#  conv2d_1 (Conv2D)           (None, None, None, 32)    4640
#
#  batch_normalization_1 (Batc  (None, None, None, 32)   128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, None, None, 32)   0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)    18496
#
#  batch_normalization_2 (Batc  (None, None, None, 64)   256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, None, None, 64)   0
#  2D)
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 16)                1040
#
#  output_dense_layer (Dense)  (None, 2)                 34
#
#  output_activation_layer (Ac  (None, 2)                0
#  tivation)
#
# =================================================================
# Total params: 25,106
# Trainable params: 24,882
# Non-trainable params: 224
# _________________________________________________________________

# %%
mll.list_model(model=model, recursive=False)
# Out:
# row   | name (type)                                       | dtype   | policy        | trainable | output shape
# 0     | input_layer              (InputLayer            ) | float32 | float32       | True      | [(None, 224, 224, 3)]
# 1     | data_augmentation        (Sequential            ) | float32 | mixed_float16 | True      | (None, None, None, 3)
# 2     | conv2d                   (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 16)
# 3     | batch_normalization      (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 16)
# 4     | max_pooling2d            (MaxPooling2D          ) | float32 | mixed_float16 | True      | (None, None, None, 16)
# 5     | conv2d_1                 (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 32)
# 6     | batch_normalization_1    (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 32)
# 7     | max_pooling2d_1          (MaxPooling2D          ) | float32 | mixed_float16 | True      | (None, None, None, 32)
# 8     | conv2d_2                 (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 64)
# 9     | batch_normalization_2    (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 64)
# 10    | max_pooling2d_2          (MaxPooling2D          ) | float32 | mixed_float16 | True      | (None, None, None, 64)
# 11    | global_average_pooling2d (GlobalAveragePooling2D) | float32 | mixed_float16 | True      | (None, 64)
# 12    | dense                    (Dense                 ) | float32 | mixed_float16 | True      | (None, 16)
# 13    | output_dense_layer       (Dense                 ) | float32 | mixed_float16 | True      | (None, 2)
# 14    | output_activation_layer  (Activation            ) | float32 | float32       | True      | (None, 2)

# %% [markdown]
# We can see that the only layer which is not trainable is the efficientnetv2-b0 model layer and all the other layers are trainable, so this setup is correct for feature extraction. In a later setup we can enable a number of layers within the efficientnetv2-b0 to increase accuracy.

# %% [markdown]
# # Create the neccesary callbacks to evaluate

# %%
tensorflow_callback = mlc.create_tensorboard_callback('cats-dogs-model-categorical-tiny')
model_checkpoint_callback = mlc.create_model_checkpoint_callback('cats-dogs-model-categorical-tiny', save_weights_only=True, save_best_only=True)
early_stopping_callback = mlc.create_early_stopping_callback()
reduce_lr_on_plateau_callback = mlc.create_reduce_lr_on_plateau_callback()

callbacks = [tensorflow_callback, model_checkpoint_callback, early_stopping_callback, reduce_lr_on_plateau_callback]
# Out:
# Saving TensorBoard log files to: ./logs/cats-dogs-model-categorical-tiny/20230612-091237

# %% [markdown]
# # Fit the mode

# %%
model_history = model.fit(
    epochs=50,
    x=train_images,
    steps_per_epoch=len(train_images),
    validation_data=test_images,
    validation_steps=int(0.15 * len(test_images)),
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 2023-06-12 09:12:42.143085: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 250/250 [==============================] - ETA: 0s - loss: 0.6644 - accuracy: 0.6039
# Epoch 1: val_loss improved from inf to 0.68802, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-01-val_loss-0.69.hdf5
# 250/250 [==============================] - 68s 268ms/step - loss: 0.6644 - accuracy: 0.6039 - val_loss: 0.6880 - val_accuracy: 0.5833 - lr: 0.0020
# Epoch 2/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6510 - accuracy: 0.6097
# Epoch 2: val_loss improved from 0.68802 to 0.67708, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-02-val_loss-0.68.hdf5
# 250/250 [==============================] - 63s 251ms/step - loss: 0.6510 - accuracy: 0.6097 - val_loss: 0.6771 - val_accuracy: 0.5729 - lr: 0.0020
# Epoch 3/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6390 - accuracy: 0.6280
# Epoch 3: val_loss did not improve from 0.67708
# 250/250 [==============================] - 62s 246ms/step - loss: 0.6390 - accuracy: 0.6280 - val_loss: 1.1203 - val_accuracy: 0.4826 - lr: 0.0020
# Epoch 4/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6258 - accuracy: 0.6471
# Epoch 4: val_loss improved from 0.67708 to 0.63426, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-04-val_loss-0.63.hdf5
# 250/250 [==============================] - 61s 244ms/step - loss: 0.6258 - accuracy: 0.6471 - val_loss: 0.6343 - val_accuracy: 0.6528 - lr: 0.0020
# Epoch 5/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6157 - accuracy: 0.6543
# Epoch 5: val_loss improved from 0.63426 to 0.61969, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-05-val_loss-0.62.hdf5
# 250/250 [==============================] - 62s 246ms/step - loss: 0.6157 - accuracy: 0.6543 - val_loss: 0.6197 - val_accuracy: 0.6562 - lr: 0.0020
# Epoch 6/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6054 - accuracy: 0.6711
# Epoch 6: val_loss did not improve from 0.61969
# 250/250 [==============================] - 62s 248ms/step - loss: 0.6054 - accuracy: 0.6711 - val_loss: 0.6505 - val_accuracy: 0.6632 - lr: 0.0020
# Epoch 7/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6002 - accuracy: 0.6751
# Epoch 7: val_loss improved from 0.61969 to 0.61152, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-07-val_loss-0.61.hdf5
# 250/250 [==============================] - 65s 258ms/step - loss: 0.6002 - accuracy: 0.6751 - val_loss: 0.6115 - val_accuracy: 0.6840 - lr: 0.0020
# Epoch 8/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5902 - accuracy: 0.6866
# Epoch 8: val_loss improved from 0.61152 to 0.58794, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-08-val_loss-0.59.hdf5
# 250/250 [==============================] - 63s 250ms/step - loss: 0.5902 - accuracy: 0.6866 - val_loss: 0.5879 - val_accuracy: 0.6979 - lr: 0.0020
# Epoch 9/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5853 - accuracy: 0.6908
# Epoch 9: val_loss did not improve from 0.58794
# 250/250 [==============================] - 64s 256ms/step - loss: 0.5853 - accuracy: 0.6908 - val_loss: 0.6260 - val_accuracy: 0.6250 - lr: 0.0020
# Epoch 10/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5773 - accuracy: 0.7000
# Epoch 10: val_loss did not improve from 0.58794
# 250/250 [==============================] - 66s 262ms/step - loss: 0.5773 - accuracy: 0.7000 - val_loss: 0.6922 - val_accuracy: 0.6389 - lr: 0.0020
# Epoch 11/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5751 - accuracy: 0.6961
# Epoch 11: val_loss did not improve from 0.58794
# 250/250 [==============================] - 62s 248ms/step - loss: 0.5751 - accuracy: 0.6961 - val_loss: 0.7212 - val_accuracy: 0.6215 - lr: 0.0020
# Epoch 12/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5626 - accuracy: 0.7096
# Epoch 12: val_loss improved from 0.58794 to 0.57583, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-12-val_loss-0.58.hdf5
# 250/250 [==============================] - 61s 245ms/step - loss: 0.5626 - accuracy: 0.7096 - val_loss: 0.5758 - val_accuracy: 0.7222 - lr: 0.0020
# Epoch 13/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5547 - accuracy: 0.7114
# Epoch 13: val_loss did not improve from 0.57583
# 250/250 [==============================] - 62s 249ms/step - loss: 0.5547 - accuracy: 0.7114 - val_loss: 0.7097 - val_accuracy: 0.6458 - lr: 0.0020
# Epoch 14/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5508 - accuracy: 0.7163
# Epoch 14: val_loss did not improve from 0.57583
# 250/250 [==============================] - 63s 253ms/step - loss: 0.5508 - accuracy: 0.7163 - val_loss: 0.7345 - val_accuracy: 0.6042 - lr: 0.0020
# Epoch 15/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5364 - accuracy: 0.7262
# Epoch 15: val_loss did not improve from 0.57583
# 250/250 [==============================] - 64s 255ms/step - loss: 0.5364 - accuracy: 0.7262 - val_loss: 0.6539 - val_accuracy: 0.6667 - lr: 0.0020
# Epoch 16/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5319 - accuracy: 0.7291
# Epoch 16: val_loss did not improve from 0.57583
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 250/250 [==============================] - 63s 253ms/step - loss: 0.5319 - accuracy: 0.7291 - val_loss: 0.6645 - val_accuracy: 0.6285 - lr: 0.0020
# Epoch 17/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.7474
# Epoch 17: val_loss improved from 0.57583 to 0.57225, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-17-val_loss-0.57.hdf5
# 250/250 [==============================] - 64s 257ms/step - loss: 0.5098 - accuracy: 0.7474 - val_loss: 0.5723 - val_accuracy: 0.7049 - lr: 0.0010
# Epoch 18/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4974 - accuracy: 0.7567
# Epoch 18: val_loss improved from 0.57225 to 0.55421, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-18-val_loss-0.55.hdf5
# 250/250 [==============================] - 64s 257ms/step - loss: 0.4974 - accuracy: 0.7567 - val_loss: 0.5542 - val_accuracy: 0.7188 - lr: 0.0010
# Epoch 19/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4860 - accuracy: 0.7651
# Epoch 19: val_loss did not improve from 0.55421
# 250/250 [==============================] - 66s 262ms/step - loss: 0.4860 - accuracy: 0.7651 - val_loss: 1.3665 - val_accuracy: 0.5521 - lr: 0.0010
# Epoch 20/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4750 - accuracy: 0.7705
# Epoch 20: val_loss did not improve from 0.55421
# 250/250 [==============================] - 66s 264ms/step - loss: 0.4750 - accuracy: 0.7705 - val_loss: 0.6136 - val_accuracy: 0.7014 - lr: 0.0010
# Epoch 21/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.7804
# Epoch 21: val_loss did not improve from 0.55421
# 250/250 [==============================] - 67s 269ms/step - loss: 0.4638 - accuracy: 0.7804 - val_loss: 0.5836 - val_accuracy: 0.6944 - lr: 0.0010
# Epoch 22/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4642 - accuracy: 0.7771
# Epoch 22: val_loss improved from 0.55421 to 0.54123, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-22-val_loss-0.54.hdf5
# 250/250 [==============================] - 67s 268ms/step - loss: 0.4642 - accuracy: 0.7771 - val_loss: 0.5412 - val_accuracy: 0.7257 - lr: 0.0010
# Epoch 23/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.7884
# Epoch 23: val_loss did not improve from 0.54123
# 250/250 [==============================] - 66s 263ms/step - loss: 0.4456 - accuracy: 0.7884 - val_loss: 0.6027 - val_accuracy: 0.7222 - lr: 0.0010
# Epoch 24/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.7857
# Epoch 24: val_loss did not improve from 0.54123
# 250/250 [==============================] - 66s 263ms/step - loss: 0.4515 - accuracy: 0.7857 - val_loss: 1.0282 - val_accuracy: 0.5590 - lr: 0.0010
# Epoch 25/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4392 - accuracy: 0.7933
# Epoch 25: val_loss did not improve from 0.54123
# 250/250 [==============================] - 66s 262ms/step - loss: 0.4392 - accuracy: 0.7933 - val_loss: 0.6626 - val_accuracy: 0.6875 - lr: 0.0010
# Epoch 26/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4313 - accuracy: 0.8024
# Epoch 26: val_loss did not improve from 0.54123
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 250/250 [==============================] - 64s 256ms/step - loss: 0.4313 - accuracy: 0.8024 - val_loss: 0.7214 - val_accuracy: 0.6424 - lr: 0.0010
# Epoch 27/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.8105
# Epoch 27: val_loss improved from 0.54123 to 0.52634, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-27-val_loss-0.53.hdf5
# 250/250 [==============================] - 65s 258ms/step - loss: 0.4155 - accuracy: 0.8105 - val_loss: 0.5263 - val_accuracy: 0.7118 - lr: 5.0000e-04
# Epoch 28/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4115 - accuracy: 0.8080
# Epoch 28: val_loss improved from 0.52634 to 0.51926, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-28-val_loss-0.52.hdf5
# 250/250 [==============================] - 65s 259ms/step - loss: 0.4115 - accuracy: 0.8080 - val_loss: 0.5193 - val_accuracy: 0.7222 - lr: 5.0000e-04
# Epoch 29/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4048 - accuracy: 0.8159
# Epoch 29: val_loss did not improve from 0.51926
# 250/250 [==============================] - 65s 259ms/step - loss: 0.4048 - accuracy: 0.8159 - val_loss: 0.5630 - val_accuracy: 0.7083 - lr: 5.0000e-04
# Epoch 30/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4046 - accuracy: 0.8144
# Epoch 30: val_loss did not improve from 0.51926
# 250/250 [==============================] - 67s 266ms/step - loss: 0.4046 - accuracy: 0.8144 - val_loss: 0.5779 - val_accuracy: 0.7222 - lr: 5.0000e-04
# Epoch 31/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3974 - accuracy: 0.8198
# Epoch 31: val_loss did not improve from 0.51926
# 250/250 [==============================] - 65s 261ms/step - loss: 0.3974 - accuracy: 0.8198 - val_loss: 0.8302 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 32/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.8092
# Epoch 32: val_loss improved from 0.51926 to 0.51516, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-32-val_loss-0.52.hdf5
# 250/250 [==============================] - 65s 258ms/step - loss: 0.4083 - accuracy: 0.8092 - val_loss: 0.5152 - val_accuracy: 0.7674 - lr: 5.0000e-04
# Epoch 33/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3936 - accuracy: 0.8209
# Epoch 33: val_loss did not improve from 0.51516
# 250/250 [==============================] - 67s 268ms/step - loss: 0.3936 - accuracy: 0.8209 - val_loss: 0.5817 - val_accuracy: 0.6979 - lr: 5.0000e-04
# Epoch 34/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.8171
# Epoch 34: val_loss did not improve from 0.51516
# 250/250 [==============================] - 66s 265ms/step - loss: 0.3901 - accuracy: 0.8171 - val_loss: 0.6835 - val_accuracy: 0.6597 - lr: 5.0000e-04
# Epoch 35/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3817 - accuracy: 0.8230
# Epoch 35: val_loss did not improve from 0.51516
# 250/250 [==============================] - 67s 270ms/step - loss: 0.3817 - accuracy: 0.8230 - val_loss: 0.6925 - val_accuracy: 0.6667 - lr: 5.0000e-04
# Epoch 36/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8244
# Epoch 36: val_loss did not improve from 0.51516
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 250/250 [==============================] - 68s 270ms/step - loss: 0.3874 - accuracy: 0.8244 - val_loss: 0.7695 - val_accuracy: 0.6389 - lr: 5.0000e-04
# Epoch 37/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3806 - accuracy: 0.8251
# Epoch 37: val_loss did not improve from 0.51516
# 250/250 [==============================] - 65s 259ms/step - loss: 0.3806 - accuracy: 0.8251 - val_loss: 0.5294 - val_accuracy: 0.7500 - lr: 2.5000e-04
# Epoch 38/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.8365
# Epoch 38: val_loss improved from 0.51516 to 0.47082, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-38-val_loss-0.47.hdf5
# 250/250 [==============================] - 67s 267ms/step - loss: 0.3701 - accuracy: 0.8365 - val_loss: 0.4708 - val_accuracy: 0.7465 - lr: 2.5000e-04
# Epoch 39/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.8313
# Epoch 39: val_loss did not improve from 0.47082
# 250/250 [==============================] - 66s 265ms/step - loss: 0.3812 - accuracy: 0.8313 - val_loss: 0.5561 - val_accuracy: 0.7292 - lr: 2.5000e-04
# Epoch 40/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3750 - accuracy: 0.8330
# Epoch 40: val_loss did not improve from 0.47082
# 250/250 [==============================] - 64s 256ms/step - loss: 0.3750 - accuracy: 0.8330 - val_loss: 0.4723 - val_accuracy: 0.7639 - lr: 2.5000e-04
# Epoch 41/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8345
# Epoch 41: val_loss did not improve from 0.47082
# 250/250 [==============================] - 65s 262ms/step - loss: 0.3649 - accuracy: 0.8345 - val_loss: 0.5138 - val_accuracy: 0.7500 - lr: 2.5000e-04
# Epoch 42/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3713 - accuracy: 0.8334
# Epoch 42: val_loss did not improve from 0.47082
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 250/250 [==============================] - 65s 260ms/step - loss: 0.3713 - accuracy: 0.8334 - val_loss: 0.4937 - val_accuracy: 0.7674 - lr: 2.5000e-04
# Epoch 43/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8342
# Epoch 43: val_loss improved from 0.47082 to 0.43729, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-43-val_loss-0.44.hdf5
# 250/250 [==============================] - 68s 270ms/step - loss: 0.3705 - accuracy: 0.8342 - val_loss: 0.4373 - val_accuracy: 0.7743 - lr: 1.2500e-04
# Epoch 44/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3658 - accuracy: 0.8356
# Epoch 44: val_loss did not improve from 0.43729
# 250/250 [==============================] - 65s 260ms/step - loss: 0.3658 - accuracy: 0.8356 - val_loss: 0.4502 - val_accuracy: 0.7882 - lr: 1.2500e-04
# Epoch 45/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3650 - accuracy: 0.8407
# Epoch 45: val_loss improved from 0.43729 to 0.42258, saving model to ./checkpoints/cats-dogs-model-categorical-tiny/model-epoch-45-val_loss-0.42.hdf5
# 250/250 [==============================] - 67s 268ms/step - loss: 0.3650 - accuracy: 0.8407 - val_loss: 0.4226 - val_accuracy: 0.7708 - lr: 1.2500e-04
# Epoch 46/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8376
# Epoch 46: val_loss did not improve from 0.42258
# 250/250 [==============================] - 67s 267ms/step - loss: 0.3637 - accuracy: 0.8376 - val_loss: 0.4324 - val_accuracy: 0.7951 - lr: 1.2500e-04
# Epoch 47/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3626 - accuracy: 0.8386
# Epoch 47: val_loss did not improve from 0.42258
# 250/250 [==============================] - 64s 257ms/step - loss: 0.3626 - accuracy: 0.8386 - val_loss: 0.4438 - val_accuracy: 0.7639 - lr: 1.2500e-04
# Epoch 48/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8340
# Epoch 48: val_loss did not improve from 0.42258
# 250/250 [==============================] - 65s 262ms/step - loss: 0.3673 - accuracy: 0.8340 - val_loss: 0.4584 - val_accuracy: 0.7743 - lr: 1.2500e-04
# Epoch 49/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3645 - accuracy: 0.8399
# Epoch 49: val_loss did not improve from 0.42258
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 250/250 [==============================] - 67s 269ms/step - loss: 0.3645 - accuracy: 0.8399 - val_loss: 0.4366 - val_accuracy: 0.7882 - lr: 1.2500e-04
# Epoch 50/50
# 250/250 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8426
# Epoch 50: val_loss did not improve from 0.42258
# 250/250 [==============================] - 67s 266ms/step - loss: 0.3603 - accuracy: 0.8426 - val_loss: 0.4392 - val_accuracy: 0.7812 - lr: 6.2500e-05

# %% [markdown]
# # Inspect the history of fitting the model

# %%
mlp.plot_history(model_history)

# %% [markdown]
# # Evaluate the model

# %%
model_evaluation = model.evaluate(x=test_images)
model_evaluation
# Out:
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4206 - accuracy: 0.8010
# [0.4205975830554962, 0.8009999990463257]

# %% [markdown]
# # Create confusion matrix on all the predictions of the test images

# %%
y_true, y_pred = mll.predict_classification_dataset_with_labels(model, test_images)
# Out:
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 85ms/step

# %%
mlp.plot_classification_confusion_matrix(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_report_f1_score(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_prediction_confidence(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_prediction_confidence_histogram(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %% [markdown]
# # Make some predictions of our own

# %%
SAMPLES_DIR = "./samples"

mli.list_dir_summary(SAMPLES_DIR)
# Out:
# There are 0 directories, and 6 in ./samples

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_1.jpeg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_2.jpeg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_3.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_1.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_2.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_3.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %% [markdown]
# # Save the model so we can perform a training

# %%
mll.save_model_alt(model=model, directory=f"./models", name="cats_dogs_categorical-tiny", format="h5")

# %%
# In case we need to load the model again
model = mll.load_model_alt(directory=f"./models", name="cats_dogs_categorical-tiny", format="h5")

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  efficientnetv2-b3 (Function  (None, None, None, 1536)  12930622
#  al)
#
#  global_average_pooling_2d (  (None, 1536)             0
#  GlobalAveragePooling2D)
#
#  output_dense_layer (Dense)  (None, 2)                 3074
#
#  output_activation_layer (Ac  (None, 2)                0
#  tivation)
#
# =================================================================
# Total params: 12,933,696
# Trainable params: 3,074
# Non-trainable params: 12,930,622
# _________________________________________________________________
