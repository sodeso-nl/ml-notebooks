# %% [markdown]
# # Setup initial code environment
#
# 1) Make sure we can reload python files when we make changes.
# 2) Load the base-notebook which will download all the python utility files and check versions of TensorFlow and Python.
# 3) Setup imports we will need for this notebook

# %%
# %run ../../base-notebook.ipynb
# Out:
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/contents.txt [666/666] -> "../../ext/contents.txt" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_callback.py [8151/8151] -> "../../ext/ml_callback.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_internal.py [2478/2478] -> "../../ext/ml_internal.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_io.py [1572/1572] -> "../../ext/ml_io.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_layer.py [7416/7416] -> "../../ext/ml_layer.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_plot.py [12765/12765] -> "../../ext/ml_plot.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_util.py [2061/2061] -> "../../ext/ml_util.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_data.py [5991/5991] -> "../../ext/ml_data.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_view.py [3304/3304] -> "../../ext/ml_view.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_analyze.py [241/241] -> "../../ext/ml_analyze.py" [1]
# FINISHED --2023-06-04 21:52:13--
# Total wall clock time: 0.2s
# Downloaded: 9 files, 43K in 0.002s (18.2 MB/s)
# TensorFlow version: 2.12.0
# Python version 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:25:13) [Clang 14.0.6 ]

# %%
import sys
import os

sys.path.append("../../ext")

import ext.ml_callback as mlc
import ext.ml_io as mli
import ext.ml_layer as mll
import ext.ml_plot as mlp
import ext.ml_util as mlu
import ext.ml_data as mld
import ext.ml_view as mlv
import ext.ml_internal as mlint

import tensorflow as tf

import opendatasets as od

from keras import Sequential, Model
from keras.optimizers import Adam
from keras.layers import Dense, Activation, RandomFlip, RandomZoom, RandomHeight, \
    RandomWidth, RandomRotation, Input, GlobalAveragePooling2D, Rescaling, Conv2D, \
    MaxPool2D, Dropout, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.utils import image_dataset_from_directory

# %% [markdown]
# # Configure mixed-precision so we can improve the performance

# %%
# BASE_MODEL_NAME is used as a folder name for saved models.
IMG_SHAPE = (224, 224)

# %%
mlu.set_mixed_precision_policy_for_gpu()
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   METAL, no compute capability (probably not an Nvidia GPU)
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %% [markdown]
# # Download the dataset from Kaggle (kaggle.json API key neccesary)

# %%
# Download the dogs and cats dataset
od.download_kaggle_dataset(dataset_url="https://www.kaggle.com/datasets/chetankv/dogs-cats-images/download?datasetVersionNumber=1",
                           data_dir="./data")
# Out:
# Downloading dogs-cats-images.zip to ./data/dogs-cats-images
# 100%|██████████| 435M/435M [00:13<00:00, 34.7MB/s]

# %% [markdown]
# # Inspect the contents of the downloaded dataset

# %%
train_dir = "./data/dogs-cats-images/dataset/training_set"
test_dir = "./data/dogs-cats-images/dataset/test_set"

# %%
mli.list_dir_summary(train_dir)
# Out:
# There are 2 directories, and 1 in ./data/dogs-cats-images/dataset/training_set
# There are 0 directories, and 4000 in ./data/dogs-cats-images/dataset/training_set/dogs
# There are 0 directories, and 4000 in ./data/dogs-cats-images/dataset/training_set/cats

# %%
mli.list_dir_summary(test_dir)
# Out:
# There are 2 directories, and 0 in ./data/dogs-cats-images/dataset/test_set
# There are 0 directories, and 1000 in ./data/dogs-cats-images/dataset/test_set/dogs
# There are 0 directories, and 1000 in ./data/dogs-cats-images/dataset/test_set/cats

# %% [markdown]
# # Show some random images from disk of the downloaded dataset

# %%
mlv.show_random_image_from_disk(target_dir=train_dir, target_class="dogs")

# %%
mlv.show_random_image_from_disk(target_dir=train_dir, target_class="cats")

# %% [markdown]
# # Create datasets for the train and test images

# %%
train_images = image_dataset_from_directory(directory=train_dir,
                             label_mode="categorical",
                             batch_size=32,
                             image_size=IMG_SHAPE,
                             shuffle=True)

test_images = image_dataset_from_directory(directory=test_dir,
                             label_mode="categorical",
                             batch_size=32,
                             image_size=IMG_SHAPE,
                             shuffle=True)

len(train_images), len(test_images)
# Out:
# Found 8000 files belonging to 2 classes.
# Metal device set to: Apple M1 Max
# Found 2000 files belonging to 2 classes.
# (250, 63)

# %% [markdown]
# # Get class-names from the dataset

# %%
class_names = mld.get_class_names_from_dataset(train_images)
class_names
# Out:
# ['cats', 'dogs']

# %% [markdown]
# # Inspect some random images from the dataset to check image size, and quality

# %%
mlv.show_images_from_dataset(dataset=train_images, shape=(4, 8))

# %% [markdown]
# # Create data augmentation layers for training

# %%
data_augementation_layer = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(.2),
    RandomHeight(.2),
    RandomWidth(.2),
    RandomZoom(.2),
    Rescaling(1/255.),
], name="data_augmentation")

# %% [markdown]
# # Create the model

# %%
def conv_layer(x, filters, kernel_size=(2, 2), padding="valid"):
    x = Conv2D(filters=filters, kernel_size=kernel_size, activation="relu", padding=padding)(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(pool_size=(2, 2))(x)
    return Dropout(rate=.25)(x)

input_layer = Input(shape=IMG_SHAPE + (3,), name="input_layer")
x = data_augementation_layer(input_layer)
x = conv_layer(x=x, filters=32, kernel_size=(3, 3))
x = conv_layer(x=x, filters=64, kernel_size=(3, 3))
x = conv_layer(x=x, filters=128, kernel_size=(3, 3))
x = GlobalAveragePooling2D()(x)
x = Dense(units=32, activation="relu")(x)
x = Dense(units=len(class_names), name="output_dense_layer")(x)
output_layer = Activation(activation="softmax", dtype=tf.float32, name="output_activation_layer")(x)

model = Model(input_layer, output_layer)

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(learning_rate=0.002),
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  conv2d (Conv2D)             (None, None, None, 32)    896
#
#  batch_normalization (BatchN  (None, None, None, 32)   128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, None, None, 32)   0
#  )
#
#  dropout (Dropout)           (None, None, None, 32)    0
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)    18496
#
#  batch_normalization_1 (Batc  (None, None, None, 64)   256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, None, None, 64)   0
#  2D)
#
#  dropout_1 (Dropout)         (None, None, None, 64)    0
#
#  conv2d_2 (Conv2D)           (None, None, None, 128)   73856
#
#  batch_normalization_2 (Batc  (None, None, None, 128)  512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, None, None, 128)  0
#  2D)
#
#  dropout_2 (Dropout)         (None, None, None, 128)   0
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 32)                4128
#
#  output_dense_layer (Dense)  (None, 2)                 66
#
#  output_activation_layer (Ac  (None, 2)                0
#  tivation)
#
# =================================================================
# Total params: 98,338
# Trainable params: 97,890
# Non-trainable params: 448
# _________________________________________________________________

# %%
mll.list_model(model=model, recursive=False)
# Out:
# row   | name (type)                                       | dtype   | policy        | trainable | output shape
# 0     | input_layer              (InputLayer            ) | float32 | float32       | True      | [(None, 224, 224, 3)]
# 1     | data_augmentation        (Sequential            ) | float32 | mixed_float16 | True      | (None, None, None, 3)
# 2     | conv2d                   (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 32)
# 3     | batch_normalization      (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 32)
# 4     | max_pooling2d            (MaxPooling2D          ) | float32 | mixed_float16 | True      | (None, None, None, 32)
# 5     | dropout                  (Dropout               ) | float32 | mixed_float16 | True      | (None, None, None, 32)
# 6     | conv2d_1                 (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 64)
# 7     | batch_normalization_1    (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 64)
# 8     | max_pooling2d_1          (MaxPooling2D          ) | float32 | mixed_float16 | True      | (None, None, None, 64)
# 9     | dropout_1                (Dropout               ) | float32 | mixed_float16 | True      | (None, None, None, 64)
# 10    | conv2d_2                 (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 128)
# 11    | batch_normalization_2    (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 128)
# 12    | max_pooling2d_2          (MaxPooling2D          ) | float32 | mixed_float16 | True      | (None, None, None, 128)
# 13    | dropout_2                (Dropout               ) | float32 | mixed_float16 | True      | (None, None, None, 128)
# 14    | global_average_pooling2d (GlobalAveragePooling2D) | float32 | mixed_float16 | True      | (None, 128)
# 15    | dense                    (Dense                 ) | float32 | mixed_float16 | True      | (None, 32)
# 16    | output_dense_layer       (Dense                 ) | float32 | mixed_float16 | True      | (None, 2)
# 17    | output_activation_layer  (Activation            ) | float32 | float32       | True      | (None, 2)

# %% [markdown]
# We can see that the only layer which is not trainable is the efficientnetv2-b0 model layer and all the other layers are trainable, so this setup is correct for feature extraction. In a later setup we can enable a number of layers within the efficientnetv2-b0 to increase accuracy.

# %% [markdown]
# # Create the neccesary callbacks to evaluate

# %%
tensorflow_callback = mlc.create_tensorboard_callback('cats-dogs-model-categorical-dropout')
model_checkpoint_callback = mlc.create_model_checkpoint_callback('cats-dogs-model-categorical-dropout', save_weights_only=True, save_best_only=True)
early_stopping_callback = mlc.create_early_stopping_callback()
reduce_lr_on_plateau_callback = mlc.create_reduce_lr_on_plateau_callback()

callbacks = [tensorflow_callback, model_checkpoint_callback, early_stopping_callback, reduce_lr_on_plateau_callback]
# Out:
# Saving TensorBoard log files to: ./logs/cats-dogs-model-categorical-dropout/20230612-113917

# %% [markdown]
# # Fit the mode

# %%
model_history = model.fit(
    epochs=50,
    x=train_images,
    steps_per_epoch=len(train_images),
    validation_data=test_images,
    validation_steps=int(0.15 * len(test_images)),
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 2023-06-12 11:39:21.568292: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 250/250 [==============================] - ETA: 0s - loss: 0.6802 - accuracy: 0.5809
# Epoch 1: val_loss improved from inf to 0.72714, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-01-val_loss-0.73.hdf5
# 250/250 [==============================] - 112s 435ms/step - loss: 0.6802 - accuracy: 0.5809 - val_loss: 0.7271 - val_accuracy: 0.5174 - lr: 0.0020
# Epoch 2/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6526 - accuracy: 0.6105
# Epoch 2: val_loss improved from 0.72714 to 0.63333, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-02-val_loss-0.63.hdf5
# 250/250 [==============================] - 107s 429ms/step - loss: 0.6526 - accuracy: 0.6105 - val_loss: 0.6333 - val_accuracy: 0.6215 - lr: 0.0020
# Epoch 3/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6382 - accuracy: 0.6352
# Epoch 3: val_loss did not improve from 0.63333
# 250/250 [==============================] - 104s 417ms/step - loss: 0.6382 - accuracy: 0.6352 - val_loss: 0.9870 - val_accuracy: 0.5417 - lr: 0.0020
# Epoch 4/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6250 - accuracy: 0.6509
# Epoch 4: val_loss did not improve from 0.63333
# 250/250 [==============================] - 106s 423ms/step - loss: 0.6250 - accuracy: 0.6509 - val_loss: 1.1326 - val_accuracy: 0.5104 - lr: 0.0020
# Epoch 5/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.6555
# Epoch 5: val_loss did not improve from 0.63333
# 250/250 [==============================] - 107s 427ms/step - loss: 0.6223 - accuracy: 0.6555 - val_loss: 0.8256 - val_accuracy: 0.5035 - lr: 0.0020
# Epoch 6/50
# 250/250 [==============================] - ETA: 0s - loss: 0.6124 - accuracy: 0.6615
# Epoch 6: val_loss did not improve from 0.63333
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 250/250 [==============================] - 107s 430ms/step - loss: 0.6124 - accuracy: 0.6615 - val_loss: 0.6762 - val_accuracy: 0.5833 - lr: 0.0020
# Epoch 7/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5996 - accuracy: 0.6798
# Epoch 7: val_loss did not improve from 0.63333
# 250/250 [==============================] - 105s 419ms/step - loss: 0.5996 - accuracy: 0.6798 - val_loss: 0.6397 - val_accuracy: 0.6215 - lr: 0.0010
# Epoch 8/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5929 - accuracy: 0.6817
# Epoch 8: val_loss improved from 0.63333 to 0.63257, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-08-val_loss-0.63.hdf5
# 250/250 [==============================] - 107s 429ms/step - loss: 0.5929 - accuracy: 0.6817 - val_loss: 0.6326 - val_accuracy: 0.6424 - lr: 0.0010
# Epoch 9/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5902 - accuracy: 0.6850
# Epoch 9: val_loss improved from 0.63257 to 0.62050, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-09-val_loss-0.62.hdf5
# 250/250 [==============================] - 105s 419ms/step - loss: 0.5902 - accuracy: 0.6850 - val_loss: 0.6205 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 10/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5821 - accuracy: 0.6946
# Epoch 10: val_loss did not improve from 0.62050
# 250/250 [==============================] - 104s 417ms/step - loss: 0.5821 - accuracy: 0.6946 - val_loss: 0.6290 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 11/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5738 - accuracy: 0.7001
# Epoch 11: val_loss improved from 0.62050 to 0.59321, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-11-val_loss-0.59.hdf5
# 250/250 [==============================] - 102s 406ms/step - loss: 0.5738 - accuracy: 0.7001 - val_loss: 0.5932 - val_accuracy: 0.6701 - lr: 0.0010
# Epoch 12/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5632 - accuracy: 0.7113
# Epoch 12: val_loss did not improve from 0.59321
# 250/250 [==============================] - 103s 410ms/step - loss: 0.5632 - accuracy: 0.7113 - val_loss: 0.6281 - val_accuracy: 0.6528 - lr: 0.0010
# Epoch 13/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5655 - accuracy: 0.7072
# Epoch 13: val_loss improved from 0.59321 to 0.55612, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-13-val_loss-0.56.hdf5
# 250/250 [==============================] - 105s 421ms/step - loss: 0.5655 - accuracy: 0.7072 - val_loss: 0.5561 - val_accuracy: 0.7049 - lr: 0.0010
# Epoch 14/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5572 - accuracy: 0.7122
# Epoch 14: val_loss did not improve from 0.55612
# 250/250 [==============================] - 103s 414ms/step - loss: 0.5572 - accuracy: 0.7122 - val_loss: 0.6704 - val_accuracy: 0.6389 - lr: 0.0010
# Epoch 15/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5481 - accuracy: 0.7186
# Epoch 15: val_loss did not improve from 0.55612
# 250/250 [==============================] - 105s 419ms/step - loss: 0.5481 - accuracy: 0.7186 - val_loss: 0.6211 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 16/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5452 - accuracy: 0.7234
# Epoch 16: val_loss did not improve from 0.55612
# 250/250 [==============================] - 104s 415ms/step - loss: 0.5452 - accuracy: 0.7234 - val_loss: 0.6007 - val_accuracy: 0.6840 - lr: 0.0010
# Epoch 17/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5402 - accuracy: 0.7251
# Epoch 17: val_loss did not improve from 0.55612
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 250/250 [==============================] - 103s 412ms/step - loss: 0.5402 - accuracy: 0.7251 - val_loss: 0.6178 - val_accuracy: 0.6840 - lr: 0.0010
# Epoch 18/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5221 - accuracy: 0.7371
# Epoch 18: val_loss did not improve from 0.55612
# 250/250 [==============================] - 104s 414ms/step - loss: 0.5221 - accuracy: 0.7371 - val_loss: 0.6054 - val_accuracy: 0.6910 - lr: 5.0000e-04
# Epoch 19/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5197 - accuracy: 0.7401
# Epoch 19: val_loss improved from 0.55612 to 0.52985, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-19-val_loss-0.53.hdf5
# 250/250 [==============================] - 102s 408ms/step - loss: 0.5197 - accuracy: 0.7401 - val_loss: 0.5299 - val_accuracy: 0.7361 - lr: 5.0000e-04
# Epoch 20/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5173 - accuracy: 0.7445
# Epoch 20: val_loss did not improve from 0.52985
# 250/250 [==============================] - 103s 413ms/step - loss: 0.5173 - accuracy: 0.7445 - val_loss: 0.6265 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 21/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5160 - accuracy: 0.7446
# Epoch 21: val_loss improved from 0.52985 to 0.52700, saving model to ./checkpoints/cats-dogs-model-categorical-dropout/model-epoch-21-val_loss-0.53.hdf5
# 250/250 [==============================] - 103s 411ms/step - loss: 0.5160 - accuracy: 0.7446 - val_loss: 0.5270 - val_accuracy: 0.7465 - lr: 5.0000e-04
# Epoch 22/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5110 - accuracy: 0.7451
# Epoch 22: val_loss did not improve from 0.52700
# 250/250 [==============================] - 103s 413ms/step - loss: 0.5110 - accuracy: 0.7451 - val_loss: 0.5465 - val_accuracy: 0.7222 - lr: 5.0000e-04
# Epoch 23/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5064 - accuracy: 0.7435
# Epoch 23: val_loss did not improve from 0.52700
# 250/250 [==============================] - 103s 412ms/step - loss: 0.5064 - accuracy: 0.7435 - val_loss: 0.5760 - val_accuracy: 0.7326 - lr: 5.0000e-04
# Epoch 24/50
# 250/250 [==============================] - ETA: 0s - loss: 0.5036 - accuracy: 0.7515
# Epoch 24: val_loss did not improve from 0.52700
# 250/250 [==============================] - 103s 412ms/step - loss: 0.5036 - accuracy: 0.7515 - val_loss: 0.6883 - val_accuracy: 0.6771 - lr: 5.0000e-04
# Epoch 25/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4948 - accuracy: 0.7561
# Epoch 25: val_loss did not improve from 0.52700
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 250/250 [==============================] - 103s 412ms/step - loss: 0.4948 - accuracy: 0.7561 - val_loss: 0.6034 - val_accuracy: 0.7188 - lr: 5.0000e-04
# Epoch 26/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.7679
# Epoch 26: val_loss did not improve from 0.52700
# 250/250 [==============================] - 101s 403ms/step - loss: 0.4810 - accuracy: 0.7679 - val_loss: 0.6294 - val_accuracy: 0.7465 - lr: 2.5000e-04
# Epoch 27/50
# 250/250 [==============================] - ETA: 0s - loss: 0.4823 - accuracy: 0.7667
# Epoch 27: val_loss did not improve from 0.52700
# 250/250 [==============================] - 104s 414ms/step - loss: 0.4823 - accuracy: 0.7667 - val_loss: 0.6349 - val_accuracy: 0.6910 - lr: 2.5000e-04

# %% [markdown]
# # Inspect the history of fitting the model

# %%
mlp.plot_history(model_history)

# %% [markdown]
# # Evaluate the model

# %%
model_evaluation = model.evaluate(x=test_images)
model_evaluation
# Out:
# 63/63 [==============================] - 8s 127ms/step - loss: 0.5370 - accuracy: 0.7410
# [0.5369935631752014, 0.7409999966621399]

# %% [markdown]
# # Create confusion matrix on all the predictions of the test images

# %%
y_true, y_pred = mll.predict_classification_dataset_with_labels(model, test_images)
# Out:
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 115ms/step

# %%
mlp.plot_classification_confusion_matrix(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_report_f1_score(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_prediction_confidence(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_prediction_confidence_histogram(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %% [markdown]
# # Make some predictions of our own

# %%
SAMPLES_DIR = "./samples"

mli.list_dir_summary(SAMPLES_DIR)
# Out:
# There are 0 directories, and 6 in ./samples

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_1.jpeg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_2.jpeg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_3.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_1.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_2.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_3.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %% [markdown]
# # Save the model so we can perform a training

# %%
mll.save_model_alt(model=model, directory=f"./models", name="cats_dogs_categorical-dropout", format="h5")

# %%
# In case we need to load the model again
model = mll.load_model_alt(directory=f"./models", name="cats_dogs_categorical-dropout", format="h5")

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  efficientnetv2-b3 (Function  (None, None, None, 1536)  12930622
#  al)
#
#  global_average_pooling_2d (  (None, 1536)             0
#  GlobalAveragePooling2D)
#
#  output_dense_layer (Dense)  (None, 2)                 3074
#
#  output_activation_layer (Ac  (None, 2)                0
#  tivation)
#
# =================================================================
# Total params: 12,933,696
# Trainable params: 3,074
# Non-trainable params: 12,930,622
# _________________________________________________________________

# %%
# %tensorboard --logdir logs
# http://localhost:6006
# Out:
# Launching TensorBoard...
