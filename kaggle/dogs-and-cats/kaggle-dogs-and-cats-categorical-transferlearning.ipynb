# %% [markdown]
# # Setup initial code environment
#
# 1) Make sure we can reload python files when we make changes.
# 2) Load the base-notebook which will download all the python utility files and check versions of TensorFlow and Python.
# 3) Setup imports we will need for this notebook

# %%
# %run ../../base-notebook.ipynb
# Out:
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/contents.txt [666/666] -> "../../ext/contents.txt" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_callback.py [8151/8151] -> "../../ext/ml_callback.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_internal.py [2478/2478] -> "../../ext/ml_internal.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_io.py [1572/1572] -> "../../ext/ml_io.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_layer.py [7416/7416] -> "../../ext/ml_layer.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_plot.py [12765/12765] -> "../../ext/ml_plot.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_util.py [2061/2061] -> "../../ext/ml_util.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_data.py [5991/5991] -> "../../ext/ml_data.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_view.py [3304/3304] -> "../../ext/ml_view.py" [1]
# 2023-06-04 21:52:13 URL:https://raw.githubusercontent.com/sodeso-nl/ml-utilities/main/ml_analyze.py [241/241] -> "../../ext/ml_analyze.py" [1]
# FINISHED --2023-06-04 21:52:13--
# Total wall clock time: 0.2s
# Downloaded: 9 files, 43K in 0.002s (18.2 MB/s)
# TensorFlow version: 2.12.0
# Python version 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:25:13) [Clang 14.0.6 ]

# %%
import sys
import os

sys.path.append("../../ext")

import ext.ml_callback as mlc
import ext.ml_io as mli
import ext.ml_layer as mll
import ext.ml_plot as mlp
import ext.ml_util as mlu
import ext.ml_data as mld
import ext.ml_view as mlv
import ext.ml_internal as mlint

import tensorflow as tf

import opendatasets as od

from keras import Sequential, Model
from keras.optimizers import Adam
from keras.layers import Dense, Activation, RandomFlip, RandomZoom, RandomHeight, \
    RandomWidth, RandomRotation, Input, GlobalAveragePooling2D
from keras.losses import categorical_crossentropy
from keras.utils import image_dataset_from_directory

# %% [markdown]
# # Configure mixed-precision so we can improve the performance

# %%
# BASE_MODEL_NAME is used as a folder name for saved models.
BASE_MODEL_NAME = "efficientnetv2b3"
IMG_SHAPE = (224, 224)

# %%
mlu.set_mixed_precision_policy_for_gpu()
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   METAL, no compute capability (probably not an Nvidia GPU)
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %% [markdown]
# # Download the dataset from Kaggle (kaggle.json API key neccesary)

# %%
# Download the dogs and cats dataset
od.download_kaggle_dataset(dataset_url="https://www.kaggle.com/datasets/chetankv/dogs-cats-images/download?datasetVersionNumber=1",
                           data_dir="./data")
# Out:
# Downloading dogs-cats-images.zip to ./data/dogs-cats-images
# 100%|██████████| 435M/435M [00:13<00:00, 34.7MB/s]

# %% [markdown]
# # Inspect the contents of the downloaded dataset

# %%
train_dir = "./data/dogs-cats-images/dataset/training_set"
test_dir = "./data/dogs-cats-images/dataset/test_set"

# %%
mli.list_dir_summary(train_dir)
# Out:
# There are 2 directories, and 1 in ./data/dogs-cats-images/dataset/training_set
# There are 0 directories, and 4000 in ./data/dogs-cats-images/dataset/training_set/dogs
# There are 0 directories, and 4000 in ./data/dogs-cats-images/dataset/training_set/cats

# %%
mli.list_dir_summary(test_dir)
# Out:
# There are 2 directories, and 0 in ./data/dogs-cats-images/dataset/test_set
# There are 0 directories, and 1000 in ./data/dogs-cats-images/dataset/test_set/dogs
# There are 0 directories, and 1000 in ./data/dogs-cats-images/dataset/test_set/cats

# %% [markdown]
# # Show some random images from disk of the downloaded dataset

# %%
mlv.show_random_image_from_disk(target_dir=train_dir, target_class="dogs")

# %%
mlv.show_random_image_from_disk(target_dir=train_dir, target_class="cats")

# %% [markdown]
# # Create datasets for the train and test images

# %%
train_images = image_dataset_from_directory(directory=train_dir,
                             label_mode="categorical",
                             batch_size=32,
                             image_size=IMG_SHAPE,
                             shuffle=True)

test_images = image_dataset_from_directory(directory=test_dir,
                             label_mode="categorical",
                             batch_size=32,
                             image_size=IMG_SHAPE,
                             shuffle=True)

len(train_images), len(test_images)
# Out:
# Found 8000 files belonging to 2 classes.
# Metal device set to: Apple M1 Max
# Found 2000 files belonging to 2 classes.
# (250, 63)

# %% [markdown]
# # Get class-names from the dataset

# %%
class_names = mld.get_class_names_from_dataset(train_images)
class_names
# Out:
# ['cats', 'dogs']

# %% [markdown]
# # Inspect some random images from the dataset to check image size, and quality

# %%
mlv.show_images_from_dataset(dataset=train_images, shape=(4, 8))

# %% [markdown]
# # Create data augmentation layers for training

# %%
# We do not need a Rescaling layer since we will be using the EfficientNet base model which already includes a rescaling layer.
data_augementation_layer = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(.2),
    RandomHeight(.2),
    RandomWidth(.2),
    RandomZoom(.2)
], name="data_augmentation")

# %% [markdown]
# # Create the model, first setup the model in such a way we can perform feature extraction first.
#
# 1. Keep activation layer of the last Dense layer separate so we can set the dtype to float32 to enable mixed-precision.
# 2. Since the data is one-hot encoded we need to use a non-sparse loss function

# %%
if BASE_MODEL_NAME == 'efficientnetv2b0':
    efficientnet_model = tf.keras.applications.efficientnet_v2.EfficientNetV2B0(include_top=False)
elif BASE_MODEL_NAME == 'efficientnetv2b3':
    efficientnet_model = tf.keras.applications.efficientnet_v2.EfficientNetV2B3(include_top=False)

efficientnet_model.trainable = False

input_layer = Input(shape=IMG_SHAPE + (3,), name="input_layer")
x = data_augementation_layer(input_layer)
x = efficientnet_model(x, training=False)
x = GlobalAveragePooling2D(name="global_average_pooling_2d")(x)
x = Dense(units=len(class_names), name="output_dense_layer")(x)
output_layer = Activation(activation="softmax", dtype=tf.float32, name="output_activation_layer")(x)

model = Model(input_layer, output_layer)

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(),
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  efficientnetv2-b3 (Function  (None, None, None, 1536)  12930622
#  al)
#
#  global_average_pooling_2d (  (None, 1536)             0
#  GlobalAveragePooling2D)
#
#  output_dense_layer (Dense)  (None, 2)                 3074
#
#  output_activation_layer (Ac  (None, 2)                0
#  tivation)
#
# =================================================================
# Total params: 12,933,696
# Trainable params: 3,074
# Non-trainable params: 12,930,622
# _________________________________________________________________

# %%
mll.list_model(model=model, recursive=False)
# Out:
# row   | name (type)                                        | dtype   | policy        | trainable | output shape
# 0     | input_layer               (InputLayer            ) | float32 | float32       | True      | [(None, 224, 224, 3)]
# 1     | data_augmentation         (Sequential            ) | float32 | mixed_float16 | True      | (None, None, None, 3)
# 2     | efficientnetv2-b3         (Functional            ) | float32 | mixed_float16 | False     | (None, None, None, 1536)
# 3     | global_average_pooling_2d (GlobalAveragePooling2D) | float32 | mixed_float16 | True      | (None, 1536)
# 4     | output_dense_layer        (Dense                 ) | float32 | mixed_float16 | True      | (None, 2)
# 5     | output_activation_layer   (Activation            ) | float32 | float32       | True      | (None, 2)

# %% [markdown]
# We can see that the only layer which is not trainable is the efficientnetv2-b0 model layer and all the other layers are trainable, so this setup is correct for feature extraction. In a later setup we can enable a number of layers within the efficientnetv2-b0 to increase accuracy.

# %% [markdown]
# # Create the neccesary callbacks to evaluate

# %%
tensorflow_callback = mlc.create_tensorboard_callback(BASE_MODEL_NAME + '-categorical')
model_checkpoint_callback = mlc.create_model_checkpoint_callback(BASE_MODEL_NAME, save_weights_only=True, save_best_only=True)
early_stopping_callback = mlc.create_early_stopping_callback()
reduce_lr_on_plateau_callback = mlc.create_reduce_lr_on_plateau_callback()

callbacks = [tensorflow_callback, model_checkpoint_callback, early_stopping_callback, reduce_lr_on_plateau_callback]
# Out:
# Saving TensorBoard log files to: ./logs/efficientnetv2b3-categorical/20230608-140201

# %% [markdown]
# # Fit the model for feature extraction

# %%
model_feature_extraction_history = model.fit(
    epochs=50,
    x=train_images,
    steps_per_epoch=len(train_images),
    validation_data=test_images,
    validation_steps=int(0.15 * len(test_images)),
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 2023-06-08 14:02:04.612717: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 250/250 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9636
# Epoch 1: val_loss improved from inf to 0.01994, saving model to ./checkpoints/efficientnetv2b3/model-epoch-01-val_loss-0.02.hdf5
# 250/250 [==============================] - 165s 644ms/step - loss: 0.1150 - accuracy: 0.9636 - val_loss: 0.0199 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 2/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0652 - accuracy: 0.9761
# Epoch 2: val_loss did not improve from 0.01994
# 250/250 [==============================] - 151s 603ms/step - loss: 0.0652 - accuracy: 0.9761 - val_loss: 0.0414 - val_accuracy: 0.9965 - lr: 0.0010
# Epoch 3/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0653 - accuracy: 0.9746
# Epoch 3: val_loss did not improve from 0.01994
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 250/250 [==============================] - 150s 601ms/step - loss: 0.0653 - accuracy: 0.9746 - val_loss: 0.0415 - val_accuracy: 0.9931 - lr: 0.0010
# Epoch 4/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9806
# Epoch 4: val_loss did not improve from 0.01994
# 250/250 [==============================] - 149s 596ms/step - loss: 0.0555 - accuracy: 0.9806 - val_loss: 0.0391 - val_accuracy: 0.9965 - lr: 2.0000e-04
# Epoch 5/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9778
# Epoch 5: val_loss did not improve from 0.01994
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 250/250 [==============================] - 153s 614ms/step - loss: 0.0579 - accuracy: 0.9778 - val_loss: 0.0371 - val_accuracy: 0.9965 - lr: 2.0000e-04
# Epoch 6/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9801
# Epoch 6: val_loss did not improve from 0.01994
# 250/250 [==============================] - 157s 630ms/step - loss: 0.0538 - accuracy: 0.9801 - val_loss: 0.0369 - val_accuracy: 0.9965 - lr: 4.0000e-05

# %% [markdown]
# # Inspect the history of fitting the feature extraction model

# %%
mlp.plot_history(model_feature_extraction_history)

# %% [markdown]
# # Evaluate the feature extraction model

# %%
model_feature_extraction_evaluation = model.evaluate(x=test_images)
# Out:
# 63/63 [==============================] - 36s 569ms/step - loss: 0.0376 - accuracy: 0.9925

# %%
model_feature_extraction_evaluation
# Out:
# [0.03756646066904068, 0.9925000071525574]

# %% [markdown]
# # Create confusion matrix on all the predictions of the test images

# %%
y_true, y_pred = mll.predict_classification_dataset(model, test_images)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 500ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 1s 524ms/step
# 1/1 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 1s 524ms/step
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 722ms/step
# 1/1 [==============================] - 1s 813ms/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 680ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 556ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 1s 541ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 630ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 666ms/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 624ms/step
# 1/1 [==============================] - 1s 635ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 621ms/step
# 1/1 [==============================] - 1s 634ms/step
# 1/1 [==============================] - 1s 1s/step

# %%
mlp.plot_classification_confusion_matrix(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_report_f1_score(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %% [markdown]
# # Make some predictions of our own

# %%
SAMPLES_DIR = "./samples"

mli.list_dir_summary(SAMPLES_DIR)
# Out:
# There are 0 directories, and 6 in ./samples

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_1.jpeg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_2.jpeg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
cat = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "cat_3.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(cat)))
mlv.show_single_image_from_nparray_or_tensor(image=cat, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_1.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_2.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %%
dog = mli.load_image_as_tensor(filename=os.path.join(SAMPLES_DIR, "dog_3.jpg"), img_shape=IMG_SHAPE, scale=False)
y = mlint.sparse_labels(model.predict(x=mld.add_batch_to_tensor(dog)))
mlv.show_single_image_from_nparray_or_tensor(image=dog, title=f"Pred: {class_names[y[0]]}")

# %% [markdown]
# # Save the model so we can perform a training

# %%
mll.save_model_alt(model=model, directory=f"./models/{BASE_MODEL_NAME}", name="cats_dogs_feature_extraction_categorical", format="h5")

# %%
# In case we need to load the model again
model = mll.load_model_alt(directory=f"./models/{BASE_MODEL_NAME}", name="cats_dogs_feature_extraction_categorical", format="h5")

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  efficientnetv2-b3 (Function  (None, None, None, 1536)  12930622
#  al)
#
#  global_average_pooling_2d (  (None, 1536)             0
#  GlobalAveragePooling2D)
#
#  output_dense_layer (Dense)  (None, 2)                 3074
#
#  output_activation_layer (Ac  (None, 2)                0
#  tivation)
#
# =================================================================
# Total params: 12,933,696
# Trainable params: 3,074
# Non-trainable params: 12,930,622
# _________________________________________________________________

# %% [markdown]
# # Change the last 10 layers to be trainable

# %%
mll.set_trainable_on_last_n_layers(model=model, n=10, trainable=True)
mll.list_model(model=model, recursive=True)
# Out:
# row   | name (type)                                         | dtype   | policy        | trainable | output shape
# 0     | input_layer                (InputLayer            ) | float32 | float32       | True      | [(None, 224, 224, 3)]
# 1     | random_flip                (RandomFlip            ) | float32 | mixed_float16 | True      | (None, 224, 224, 3)
# 2     | random_rotation            (RandomRotation        ) | float32 | mixed_float16 | True      | (None, 224, 224, 3)
# 3     | random_height              (RandomHeight          ) | float32 | mixed_float16 | True      | (None, None, 224, 3)
# 4     | random_width               (RandomWidth           ) | float32 | mixed_float16 | True      | (None, None, None, 3)
# 5     | random_zoom                (RandomZoom            ) | float32 | mixed_float16 | True      | (None, None, None, 3)
# 6     | input_1                    (InputLayer            ) | float32 | float32       | True      | [(None, None, None, 3)]
# 7     | rescaling                  (Rescaling             ) | float32 | mixed_float16 | False     | (None, None, None, 3)
# 8     | normalization              (Normalization         ) | float32 | mixed_float16 | False     | (None, None, None, 3)
# 9     | stem_conv                  (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 10    | stem_bn                    (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 11    | stem_activation            (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 12    | block1a_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 13    | block1a_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 14    | block1a_project_activation (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 15    | block1b_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 16    | block1b_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 17    | block1b_project_activation (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 18    | block1b_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 19    | block1b_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 16)
# 20    | block2a_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 64)
# 21    | block2a_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 64)
# 22    | block2a_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 64)
# 23    | block2a_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 24    | block2a_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 25    | block2b_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 26    | block2b_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 27    | block2b_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 28    | block2b_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 29    | block2b_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 30    | block2b_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 31    | block2b_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 32    | block2c_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 33    | block2c_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 34    | block2c_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 35    | block2c_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 36    | block2c_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 37    | block2c_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 38    | block2c_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 40)
# 39    | block3a_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 40    | block3a_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 41    | block3a_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 160)
# 42    | block3a_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 43    | block3a_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 44    | block3b_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 45    | block3b_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 46    | block3b_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 47    | block3b_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 48    | block3b_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 49    | block3b_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 50    | block3b_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 51    | block3c_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 52    | block3c_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 53    | block3c_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 54    | block3c_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 55    | block3c_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 56    | block3c_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 57    | block3c_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 56)
# 58    | block4a_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 59    | block4a_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 60    | block4a_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 61    | block4a_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 62    | block4a_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 63    | block4a_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 64    | block4a_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 224)
# 65    | block4a_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 224)
# 66    | block4a_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 14)
# 67    | block4a_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 224)
# 68    | block4a_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 224)
# 69    | block4a_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 70    | block4a_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 71    | block4b_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 72    | block4b_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 73    | block4b_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 74    | block4b_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 75    | block4b_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 76    | block4b_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 77    | block4b_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 448)
# 78    | block4b_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 79    | block4b_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 28)
# 80    | block4b_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 81    | block4b_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 82    | block4b_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 83    | block4b_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 84    | block4b_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 85    | block4b_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 86    | block4c_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 87    | block4c_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 88    | block4c_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 89    | block4c_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 90    | block4c_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 91    | block4c_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 92    | block4c_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 448)
# 93    | block4c_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 94    | block4c_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 28)
# 95    | block4c_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 96    | block4c_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 97    | block4c_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 98    | block4c_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 99    | block4c_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 100   | block4c_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 101   | block4d_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 102   | block4d_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 103   | block4d_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 104   | block4d_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 105   | block4d_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 106   | block4d_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 107   | block4d_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 448)
# 108   | block4d_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 109   | block4d_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 28)
# 110   | block4d_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 111   | block4d_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 112   | block4d_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 113   | block4d_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 114   | block4d_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 115   | block4d_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 116   | block4e_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 117   | block4e_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 118   | block4e_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 119   | block4e_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 120   | block4e_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 121   | block4e_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 122   | block4e_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 448)
# 123   | block4e_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 124   | block4e_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 28)
# 125   | block4e_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 448)
# 126   | block4e_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 448)
# 127   | block4e_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 128   | block4e_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 129   | block4e_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 130   | block4e_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 112)
# 131   | block5a_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 672)
# 132   | block5a_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 672)
# 133   | block5a_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 672)
# 134   | block5a_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 672)
# 135   | block5a_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 672)
# 136   | block5a_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 672)
# 137   | block5a_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 672)
# 138   | block5a_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 672)
# 139   | block5a_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 28)
# 140   | block5a_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 672)
# 141   | block5a_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 672)
# 142   | block5a_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 143   | block5a_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 144   | block5b_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 145   | block5b_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 146   | block5b_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 147   | block5b_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 148   | block5b_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 149   | block5b_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 150   | block5b_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 816)
# 151   | block5b_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 152   | block5b_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 34)
# 153   | block5b_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 154   | block5b_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 155   | block5b_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 156   | block5b_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 157   | block5b_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 158   | block5b_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 159   | block5c_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 160   | block5c_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 161   | block5c_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 162   | block5c_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 163   | block5c_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 164   | block5c_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 165   | block5c_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 816)
# 166   | block5c_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 167   | block5c_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 34)
# 168   | block5c_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 169   | block5c_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 170   | block5c_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 171   | block5c_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 172   | block5c_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 173   | block5c_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 174   | block5d_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 175   | block5d_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 176   | block5d_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 177   | block5d_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 178   | block5d_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 179   | block5d_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 180   | block5d_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 816)
# 181   | block5d_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 182   | block5d_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 34)
# 183   | block5d_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 184   | block5d_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 185   | block5d_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 186   | block5d_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 187   | block5d_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 188   | block5d_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 189   | block5e_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 190   | block5e_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 191   | block5e_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 192   | block5e_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 193   | block5e_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 194   | block5e_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 195   | block5e_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 816)
# 196   | block5e_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 197   | block5e_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 34)
# 198   | block5e_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 199   | block5e_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 200   | block5e_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 201   | block5e_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 202   | block5e_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 203   | block5e_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 204   | block5f_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 205   | block5f_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 206   | block5f_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 207   | block5f_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 208   | block5f_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 209   | block5f_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 210   | block5f_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 816)
# 211   | block5f_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 212   | block5f_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 34)
# 213   | block5f_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 214   | block5f_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 215   | block5f_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 216   | block5f_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 217   | block5f_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 218   | block5f_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 219   | block5g_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 220   | block5g_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 221   | block5g_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 222   | block5g_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 223   | block5g_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 224   | block5g_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 225   | block5g_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 816)
# 226   | block5g_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 227   | block5g_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 34)
# 228   | block5g_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 229   | block5g_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 230   | block5g_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 231   | block5g_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 232   | block5g_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 233   | block5g_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 136)
# 234   | block6a_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 235   | block6a_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 236   | block6a_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 237   | block6a_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 238   | block6a_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 239   | block6a_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 240   | block6a_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 816)
# 241   | block6a_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 242   | block6a_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 34)
# 243   | block6a_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 816)
# 244   | block6a_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 816)
# 245   | block6a_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 246   | block6a_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 247   | block6b_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 248   | block6b_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 249   | block6b_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 250   | block6b_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 251   | block6b_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 252   | block6b_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 253   | block6b_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 254   | block6b_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 255   | block6b_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 256   | block6b_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 257   | block6b_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 258   | block6b_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 259   | block6b_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 260   | block6b_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 261   | block6b_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 262   | block6c_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 263   | block6c_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 264   | block6c_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 265   | block6c_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 266   | block6c_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 267   | block6c_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 268   | block6c_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 269   | block6c_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 270   | block6c_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 271   | block6c_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 272   | block6c_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 273   | block6c_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 274   | block6c_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 275   | block6c_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 276   | block6c_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 277   | block6d_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 278   | block6d_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 279   | block6d_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 280   | block6d_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 281   | block6d_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 282   | block6d_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 283   | block6d_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 284   | block6d_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 285   | block6d_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 286   | block6d_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 287   | block6d_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 288   | block6d_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 289   | block6d_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 290   | block6d_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 291   | block6d_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 292   | block6e_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 293   | block6e_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 294   | block6e_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 295   | block6e_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 296   | block6e_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 297   | block6e_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 298   | block6e_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 299   | block6e_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 300   | block6e_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 301   | block6e_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 302   | block6e_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 303   | block6e_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 304   | block6e_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 305   | block6e_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 306   | block6e_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 307   | block6f_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 308   | block6f_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 309   | block6f_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 310   | block6f_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 311   | block6f_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 312   | block6f_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 313   | block6f_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 314   | block6f_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 315   | block6f_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 316   | block6f_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 317   | block6f_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 318   | block6f_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 319   | block6f_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 320   | block6f_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 321   | block6f_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 322   | block6g_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 323   | block6g_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 324   | block6g_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 325   | block6g_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 326   | block6g_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 327   | block6g_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 328   | block6g_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 329   | block6g_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 330   | block6g_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 331   | block6g_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 332   | block6g_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 333   | block6g_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 334   | block6g_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 335   | block6g_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 336   | block6g_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 337   | block6h_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 338   | block6h_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 339   | block6h_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 340   | block6h_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 341   | block6h_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 342   | block6h_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 343   | block6h_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 344   | block6h_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 345   | block6h_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 346   | block6h_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 347   | block6h_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 348   | block6h_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 349   | block6h_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 350   | block6h_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 351   | block6h_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 352   | block6i_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 353   | block6i_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 354   | block6i_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 355   | block6i_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 356   | block6i_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 357   | block6i_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 358   | block6i_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 359   | block6i_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 360   | block6i_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 361   | block6i_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 362   | block6i_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 363   | block6i_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 364   | block6i_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 365   | block6i_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 366   | block6i_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 367   | block6j_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 368   | block6j_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 369   | block6j_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 370   | block6j_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 371   | block6j_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 372   | block6j_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 373   | block6j_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 374   | block6j_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 375   | block6j_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 376   | block6j_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 377   | block6j_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 378   | block6j_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 379   | block6j_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 380   | block6j_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 381   | block6j_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 382   | block6k_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 383   | block6k_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 384   | block6k_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 385   | block6k_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 386   | block6k_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 387   | block6k_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 388   | block6k_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 389   | block6k_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 390   | block6k_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 391   | block6k_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 392   | block6k_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 393   | block6k_project_conv       (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 394   | block6k_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 395   | block6k_drop               (Dropout               ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 396   | block6k_add                (Add                   ) | float32 | mixed_float16 | False     | (None, None, None, 232)
# 397   | block6l_expand_conv        (Conv2D                ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 398   | block6l_expand_bn          (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 399   | block6l_expand_activation  (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 400   | block6l_dwconv2            (DepthwiseConv2D       ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 401   | block6l_bn                 (BatchNormalization    ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 402   | block6l_activation         (Activation            ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 403   | block6l_se_squeeze         (GlobalAveragePooling2D) | float32 | mixed_float16 | False     | (None, 1392)
# 404   | block6l_se_reshape         (Reshape               ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 405   | block6l_se_reduce          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 58)
# 406   | block6l_se_expand          (Conv2D                ) | float32 | mixed_float16 | False     | (None, 1, 1, 1392)
# 407   | block6l_se_excite          (Multiply              ) | float32 | mixed_float16 | False     | (None, None, None, 1392)
# 408   | block6l_project_conv       (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 232)
# 409   | block6l_project_bn         (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 232)
# 410   | block6l_drop               (Dropout               ) | float32 | mixed_float16 | True      | (None, None, None, 232)
# 411   | block6l_add                (Add                   ) | float32 | mixed_float16 | True      | (None, None, None, 232)
# 412   | top_conv                   (Conv2D                ) | float32 | mixed_float16 | True      | (None, None, None, 1536)
# 413   | top_bn                     (BatchNormalization    ) | float32 | mixed_float16 | True      | (None, None, None, 1536)
# 414   | top_activation             (Activation            ) | float32 | mixed_float16 | True      | (None, None, None, 1536)
# 415   | global_average_pooling_2d  (GlobalAveragePooling2D) | float32 | mixed_float16 | True      | (None, 1536)
# 416   | output_dense_layer         (Dense                 ) | float32 | mixed_float16 | True      | (None, 2)
# 417   | output_activation_layer    (Activation            ) | float32 | float32       | True      | (None, 2)

# %% [markdown]
# # Recompile the model so we can use a lower learning rate which is adviced after performing feature extraction after transfer learning. The learning rate should be 10x lower then the learning rate used for feature extraction.

# %%
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(0.001 * 0.10),
              metrics=["accuracy"])

# %% [markdown]
# # Train the model further

# %%
model_2nd_pass_history = model.fit(epochs=50,
                                   x=train_images,
                                   steps_per_epoch=len(train_images),
                                   validation_data=test_images,
                                   validation_steps=int(.5 * len(test_images)),
                                   initial_epoch=len(model_feature_extraction_history.epoch) - 1,
                                   callbacks=callbacks)
# Out:
# Epoch 6/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9743
# Epoch 6: val_loss did not improve from 0.01994
# 250/250 [==============================] - 198s 776ms/step - loss: 0.0651 - accuracy: 0.9743 - val_loss: 0.0330 - val_accuracy: 0.9940 - lr: 1.0000e-04
# Epoch 7/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0534 - accuracy: 0.9803
# Epoch 7: val_loss did not improve from 0.01994
# 250/250 [==============================] - 195s 778ms/step - loss: 0.0534 - accuracy: 0.9803 - val_loss: 0.0311 - val_accuracy: 0.9950 - lr: 1.0000e-04
# Epoch 8/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9804
# Epoch 8: val_loss did not improve from 0.01994
# 250/250 [==============================] - 177s 708ms/step - loss: 0.0481 - accuracy: 0.9804 - val_loss: 0.0336 - val_accuracy: 0.9940 - lr: 1.0000e-04
# Epoch 9/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9837
# Epoch 9: val_loss did not improve from 0.01994
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 250/250 [==============================] - 176s 706ms/step - loss: 0.0405 - accuracy: 0.9837 - val_loss: 0.0333 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 10/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9841
# Epoch 10: val_loss did not improve from 0.01994
# 250/250 [==============================] - 186s 742ms/step - loss: 0.0419 - accuracy: 0.9841 - val_loss: 0.0338 - val_accuracy: 0.9929 - lr: 2.0000e-05
# Epoch 11/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9836
# Epoch 11: val_loss did not improve from 0.01994
# 250/250 [==============================] - 181s 726ms/step - loss: 0.0406 - accuracy: 0.9836 - val_loss: 0.0234 - val_accuracy: 0.9960 - lr: 2.0000e-05
# Epoch 12/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9845
# Epoch 12: val_loss did not improve from 0.01994
# 250/250 [==============================] - 178s 714ms/step - loss: 0.0411 - accuracy: 0.9845 - val_loss: 0.0323 - val_accuracy: 0.9919 - lr: 2.0000e-05
# Epoch 13/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9849
# Epoch 13: val_loss did not improve from 0.01994
# 250/250 [==============================] - 171s 685ms/step - loss: 0.0411 - accuracy: 0.9849 - val_loss: 0.0216 - val_accuracy: 0.9960 - lr: 2.0000e-05
# Epoch 14/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9862
# Epoch 14: val_loss did not improve from 0.01994
# 250/250 [==============================] - 168s 673ms/step - loss: 0.0358 - accuracy: 0.9862 - val_loss: 0.0317 - val_accuracy: 0.9940 - lr: 2.0000e-05
# Epoch 15/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9860
# Epoch 15: val_loss did not improve from 0.01994
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 250/250 [==============================] - 169s 677ms/step - loss: 0.0370 - accuracy: 0.9860 - val_loss: 0.0290 - val_accuracy: 0.9950 - lr: 2.0000e-05
# Epoch 16/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9866
# Epoch 16: val_loss did not improve from 0.01994
# 250/250 [==============================] - 169s 674ms/step - loss: 0.0371 - accuracy: 0.9866 - val_loss: 0.0335 - val_accuracy: 0.9919 - lr: 4.0000e-06
# Epoch 17/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9868
# Epoch 17: val_loss did not improve from 0.01994
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 250/250 [==============================] - 170s 681ms/step - loss: 0.0355 - accuracy: 0.9868 - val_loss: 0.0289 - val_accuracy: 0.9940 - lr: 4.0000e-06
# Epoch 18/50
# 250/250 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9861
# Epoch 18: val_loss did not improve from 0.01994
# 250/250 [==============================] - 169s 676ms/step - loss: 0.0350 - accuracy: 0.9861 - val_loss: 0.0303 - val_accuracy: 0.9929 - lr: 8.0000e-07

# %% [markdown]
# # Save the 2nd pass model in case we want to continue

# %%
mll.save_model_alt(model=model, directory=f"./models/{BASE_MODEL_NAME}", name="cats_dogs_2nd_pass_categorical", format="h5")

# %%
# In case we need to load the model again
model = mll.load_model_alt(directory=f"./models/{BASE_MODEL_NAME}", name="cats_dogs_2nd_pass_categorical", format="h5")

# %%
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(0.001 * 0.10),
              metrics=["accuracy"])

# %% [markdown]
# # Inspect the history of fitting the feature extraction model and the 2nd pass

# %%
mlp.plot_consecutive_histories(histories=[model_feature_extraction_history, model_2nd_pass_history], labels=["FE", "2ND"])

# %% [markdown]
# # Evaluate the 2nd pass model

# %%
model_2nd_pass_evaluation = model.evaluate(x=test_images)
model_2nd_pass_evaluation
# Out:
# 63/63 [==============================] - 36s 550ms/step - loss: 0.0240 - accuracy: 0.9940
# [0.024035589769482613, 0.9940000176429749]

# %%
# Compare both the feature extraction evaluation and the 2nd pass evaluation
model_feature_extraction_evaluation, model_2nd_pass_evaluation
# Out:
# ([0.03756646066904068, 0.9925000071525574],
#  [0.024035589769482613, 0.9940000176429749])

# %% [markdown]
# # Create confusion matrix on all the predictions of the test images

# %%
y_true, y_pred = mll.predict_classification_dataset(model, test_images)
mlp.plot_classification_confusion_matrix(y_true=y_true, y_pred=y_pred, class_names=class_names)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 0s 493ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 1s 541ms/step
# 1/1 [==============================] - 1s 635ms/step
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 500ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 0s 491ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 498ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 486ms/step
# 1/1 [==============================] - 0s 493ms/step
# 1/1 [==============================] - 0s 491ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 1s 546ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 0s 494ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 481ms/step
# 1/1 [==============================] - 0s 496ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 484ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 0s 494ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 495ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 496ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 1s 515ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 1s 1s/step

# %%
mlp.plot_classification_prediction_confidence(y_true=y_true, y_pred=y_pred, class_names=class_names)

# %%
mlp.plot_classification_prediction_confidence_histogram(y_true=y_true, y_pred=y_pred, class_names=class_names, figsize=(8, 4))
